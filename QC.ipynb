# %%
import FlowCytometryTools
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
from FlowCytometryTools import FCMeasurement, ThresholdGate
import random
import numpy as np
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
import umap.umap_ as umap
import hdbscan
import umap.plot
from collections import Counter
from matplotlib.pyplot import figure
import matplotlib
from matplotlib.pyplot import cm
from unidip import UniDip
import scipy.stats as stat

def unimodal(dat):
        
        dat = list(dat)       
        dat = np.msort(dat)
        intervals = UniDip(dat, alpha=0.05).run()
        return intervals
    
def spread(dat):
    IQR = stat.iqr(dat)
    return IQR
    
good_markers = []
bad_markers = []    
sizes = []
os.chdir(r'C:\Users\mp268043\Jupyter\tests\VAC2022\contrôles\files')
for file_BL, file_D28 in zip(os.listdir(r'C:\Users\mp268043\Jupyter\tests\VAC2022\contrôles\files\BL'), os.listdir(r'C:\Users\mp268043\Jupyter\tests\VAC2022\contrôles\files\D28')) :
    print('baseline: ' + file_BL + ' day 28: ' + file_D28)
    
    BL = FCMeasurement(ID='BL', datafile=r'BL/' + file_BL)
    BL = BL.data
    
    D28 = FCMeasurement(ID='D28', datafile=r'D28/' + file_D28)
    D28 = D28.data
    
    indexes = random.sample(range(0, min(len(BL), len(D28))), min(len(BL), len(D28)))
    
    #indexes = random.sample(range(0, min(len(BL), len(D28))), 20000)
    sizes.append(len(indexes))
    BL = BL.iloc[indexes,]
    D28 = D28.iloc[indexes,]
    
    BL = BL.drop(['Time','Event_length','Center','Offset','Width',
                      'Residual','File_Number','102Pd','103Rh','104Pd',
                      '105Pd','106Pd','108Pd','110Pd','190BCKG',
                      '191Ir','193Ir','80ArAr','131Xe_conta','140Ce_Beads',
                      '208Pb_Conta','127I_Conta','138Ba_Conta'], axis = 1)
    
    D28 = D28.drop(['Time','Event_length','Center','Offset','Width',
                      'Residual','File_Number','102Pd','103Rh','104Pd',
                      '105Pd','106Pd','108Pd','110Pd','190BCKG',
                      '191Ir','193Ir','80ArAr','131Xe_conta','140Ce_Beads',
                      '208Pb_Conta','127I_Conta','138Ba_Conta'], axis = 1)
    
    
    for mbl, md28 in zip(BL, D28):
        print(' - '+ str(mbl))

    
        if (unimodal(BL[str(mbl)]) == unimodal(BL[str(md28)])) & ((spread(BL[str(mbl)])<2*spread(D28[str(md28)])) & (spread(D28[str(mbl)]) < 2*spread(BL[str(md28)]))) & ((BL[str(mbl)].mean() < 10*D28[str(md28)].mean()) & (D28[str(md28)].mean() < 10*BL[str(mbl)].mean())):
            
            if mbl in bad_markers:
                print('bad')
            else:
            
                try:
                    good_markers.remove(mbl)
                except ValueError:
                    pass    
                good_markers.append(mbl)
                print('good')
        else:
            try:
                bad_markers.remove(mbl)
            except ValueError:
                pass
            
            try:
                good_markers.remove(mbl)
            except ValueError:
                pass
            bad_markers.append(mbl)
            print('bad')
                    
    
                
textfile = open("QC_results.txt", "w")
textfile.write('GOOD:' + "\n")
for element in np.unique(good_markers):
    
    textfile.write(element + "\n")
textfile.write("\n")   
textfile.write('BAD:' + "\n")

for element in np.unique(bad_markers):
    textfile.write(element + "\n")

textfile.write("\n")
textfile.write("N CELLS:")
textfile.write("\n")
textfile.write(str(sizes))
textfile.close()
# Out:
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1996: invalid continuation byte
# C:\Users\mp268043\Anaconda3\lib\site-packages\fcsparser\api.py:214: UserWarning: The first two characters were:
#  \$. The last two characters were: \
# Parser expects the same delimiter character in beginning and end of TEXT segment. This file may be parsed incorrectly!
#   warnings.warn(msg)
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1996: invalid continuation byte
# baseline: BL_VAC2022_Ctrl_SecondRand-_1__Beads-Eosino-.fcs day 28: D28_VAC2022_Ctrl_SecondRand-_1__Beads-Eosino-.fcs
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1994: invalid continuation byte
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1994: invalid continuation byte
#  - 89Y_CD45
# good
#  - 141Pr_CD66
# bad
#  - 142Nd_HLA-DR
# good
#  - 143Nd_CD3
# good
#  - 144Nd_CD64
# bad
#  - 145Nd_CD34
# good
#  - 146Nd_Histone_3
# good
#  - 147Sm_CD123
# good
#  - 148Nd_CD101
# good
#  - 149Sm_CD38
# good
#  - 150Nd_CD2
# good
#  - 151Eu_Ki67
# good
#  - 152Sm_CD10
# good
#  - 153Eu_CD117
# good
#  - 154Sm_CX3CR1
# good
#  - 155Gd_E3L
# bad
#  - 156Gd_CD172a
# good
#  - 158Gd_CD45RA
# bad
#  - 159Tb_CD14
# good
#  - 160Gd_Siglec1
# good
#  - 161Dy_CD1c
# good
#  - 162Dy_H4K20me3
# bad
#  - 163Dy_CD32
# good
#  - 164Dy_CLEC12A
# good
#  - 165Ho_CD90
# good
#  - 166Er_H3K27ac
# good
#  - 167Er_CD16
# good
#  - 168Er_CD11c
# good
#  - 169Tm_CD33
# bad
#  - 170Er_Histone_4
# bad
#  - 171Yb_CD115
# good
#  - 172Yb_BDCA2
# good
#  - 173Yb_CD49d
# bad
#  - 174Yb_H3K27me3
# good
#  - 175Lu_H3K4me3
# good
#  - 176Yb_CADM1
# good
#  - 194Pt_CD20
# good
#  - 198Pt_CD8
# bad
#  - 209Bi_CD11b
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1994: invalid continuation byte
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1994: invalid continuation byte
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1992: invalid continuation byte
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1992: invalid continuation byte
# bad
# baseline: BL_VAC2022_Ctrl_SecondRand-_1__B_cells.fcs day 28: D28_VAC2022_Ctrl_SecondRand-_1__B_cells.fcs
#  - 89Y_CD45
# good
#  - 141Pr_CD66
# bad
#  - 142Nd_HLA-DR
# good
#  - 143Nd_CD3
# good
#  - 144Nd_CD64
# bad
#  - 145Nd_CD34
# good
#  - 146Nd_Histone_3
# good
#  - 147Sm_CD123
# good
#  - 148Nd_CD101
# good
#  - 149Sm_CD38
# bad
#  - 150Nd_CD2
# bad
#  - 151Eu_Ki67
# good
#  - 152Sm_CD10
# good
#  - 153Eu_CD117
# good
#  - 154Sm_CX3CR1
# good
#  - 155Gd_E3L
# bad
#  - 156Gd_CD172a
# good
#  - 158Gd_CD45RA
# bad
#  - 159Tb_CD14
# good
#  - 160Gd_Siglec1
# good
#  - 161Dy_CD1c
# good
#  - 162Dy_H4K20me3
# bad
#  - 163Dy_CD32
# good
#  - 164Dy_CLEC12A
# good
#  - 165Ho_CD90
# good
#  - 166Er_H3K27ac
# good
#  - 167Er_CD16
# good
#  - 168Er_CD11c
# bad
#  - 169Tm_CD33
# bad
#  - 170Er_Histone_4
# bad
#  - 171Yb_CD115
# good
#  - 172Yb_BDCA2
# good
#  - 173Yb_CD49d
# bad
#  - 174Yb_H3K27me3
# bad
#  - 175Lu_H3K4me3
# good
#  - 176Yb_CADM1
# good
#  - 194Pt_CD20
# good
#  - 198Pt_CD8
# bad
#  - 209Bi_CD11b
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1996: invalid continuation byte
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1996: invalid continuation byte
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1994: invalid continuation byte
# bad
# baseline: BL_VAC2022_Ctrl_SecondRand-_1__CD3+.fcs day 28: D28_VAC2022_Ctrl_SecondRand-_1__CD3+.fcs
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1994: invalid continuation byte
#  - 89Y_CD45
# good
#  - 141Pr_CD66
# bad
#  - 142Nd_HLA-DR
# good
#  - 143Nd_CD3
# good
#  - 144Nd_CD64
# bad
#  - 145Nd_CD34
# good
#  - 146Nd_Histone_3
# good
#  - 147Sm_CD123
# good
#  - 148Nd_CD101
# good
#  - 149Sm_CD38
# bad
#  - 150Nd_CD2
# bad
#  - 151Eu_Ki67
# good
#  - 152Sm_CD10
# good
#  - 153Eu_CD117
# good
#  - 154Sm_CX3CR1
# good
#  - 155Gd_E3L
# bad
#  - 156Gd_CD172a
# good
#  - 158Gd_CD45RA
# bad
#  - 159Tb_CD14
# good
#  - 160Gd_Siglec1
# good
#  - 161Dy_CD1c
# good
#  - 162Dy_H4K20me3
# bad
#  - 163Dy_CD32
# good
#  - 164Dy_CLEC12A
# good
#  - 165Ho_CD90
# good
#  - 166Er_H3K27ac
# bad
#  - 167Er_CD16
# good
#  - 168Er_CD11c
# bad
#  - 169Tm_CD33
# bad
#  - 170Er_Histone_4
# bad
#  - 171Yb_CD115
# bad
#  - 172Yb_BDCA2
# good
#  - 173Yb_CD49d
# bad
#  - 174Yb_H3K27me3
# bad
#  - 175Lu_H3K4me3
# good
#  - 176Yb_CADM1
# good
#  - 194Pt_CD20
# good
#  - 198Pt_CD8
# bad
#  - 209Bi_CD11b
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1995: invalid continuation byte
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1995: invalid continuation byte
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1992: invalid continuation byte
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1992: invalid continuation byte
# bad
# baseline: BL_VAC2022_Ctrl_SecondRand-_1__CD66+.fcs day 28: D28_VAC2022_Ctrl_SecondRand-_1__CD66+.fcs
#  - 89Y_CD45
# bad
#  - 141Pr_CD66
# bad
#  - 142Nd_HLA-DR
# bad
#  - 143Nd_CD3
# good
#  - 144Nd_CD64
# bad
#  - 145Nd_CD34
# good
#  - 146Nd_Histone_3
# good
#  - 147Sm_CD123
# good
#  - 148Nd_CD101
# good
#  - 149Sm_CD38
# bad
#  - 150Nd_CD2
# bad
#  - 151Eu_Ki67
# good
#  - 152Sm_CD10
# good
#  - 153Eu_CD117
# good
#  - 154Sm_CX3CR1
# bad
#  - 155Gd_E3L
# bad
#  - 156Gd_CD172a
# good
#  - 158Gd_CD45RA
# bad
#  - 159Tb_CD14
# good
#  - 160Gd_Siglec1
# good
#  - 161Dy_CD1c
# good
#  - 162Dy_H4K20me3
# bad
#  - 163Dy_CD32
# bad
#  - 164Dy_CLEC12A
# good
#  - 165Ho_CD90
# good
#  - 166Er_H3K27ac
# bad
#  - 167Er_CD16
# good
#  - 168Er_CD11c
# bad
#  - 169Tm_CD33
# bad
#  - 170Er_Histone_4
# bad
#  - 171Yb_CD115
# bad
#  - 172Yb_BDCA2
# good
#  - 173Yb_CD49d
# bad
#  - 174Yb_H3K27me3
# bad
#  - 175Lu_H3K4me3
# bad
#  - 176Yb_CADM1
# good
#  - 194Pt_CD20
# good
#  - 198Pt_CD8
# bad
#  - 209Bi_CD11b
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1995: invalid continuation byte
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1995: invalid continuation byte
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1993: invalid continuation byte
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1993: invalid continuation byte
# bad
# baseline: BL_VAC2022_Ctrl_SecondRand-_1__DR+20-.fcs day 28: D28_VAC2022_Ctrl_SecondRand-_1__DR+20-.fcs
#  - 89Y_CD45
# bad
#  - 141Pr_CD66
# bad
#  - 142Nd_HLA-DR
# bad
#  - 143Nd_CD3
# good
#  - 144Nd_CD64
# bad
#  - 145Nd_CD34
# good
#  - 146Nd_Histone_3
# good
#  - 147Sm_CD123
# good
#  - 148Nd_CD101
# good
#  - 149Sm_CD38
# bad
#  - 150Nd_CD2
# bad
#  - 151Eu_Ki67
# bad
#  - 152Sm_CD10
# good
#  - 153Eu_CD117
# good
#  - 154Sm_CX3CR1
# bad
#  - 155Gd_E3L
# bad
#  - 156Gd_CD172a
# good
#  - 158Gd_CD45RA
# bad
#  - 159Tb_CD14
# bad
#  - 160Gd_Siglec1
# good
#  - 161Dy_CD1c
# bad
#  - 162Dy_H4K20me3
# bad
#  - 163Dy_CD32
# bad
#  - 164Dy_CLEC12A
# good
#  - 165Ho_CD90
# good
#  - 166Er_H3K27ac
# bad
#  - 167Er_CD16
# good
#  - 168Er_CD11c
# bad
#  - 169Tm_CD33
# bad
#  - 170Er_Histone_4
# bad
#  - 171Yb_CD115
# bad
#  - 172Yb_BDCA2
# good
#  - 173Yb_CD49d
# bad
#  - 174Yb_H3K27me3
# bad
#  - 175Lu_H3K4me3
# bad
#  - 176Yb_CADM1
# good
#  - 194Pt_CD20
# good
#  - 198Pt_CD8
# bad
#  - 209Bi_CD11b
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1995: invalid continuation byte
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1995: invalid continuation byte
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1993: invalid continuation byte
# Encountered an illegal utf-8 byte in the header.
#  Illegal utf-8 characters will be ignored.
# 'utf-8' codec can't decode byte 0xe9 in position 1993: invalid continuation byte
# bad
# baseline: BL_VAC2022_Ctrl_SecondRand-_1__NEG-NEG.fcs day 28: D28_VAC2022_Ctrl_SecondRand-_1__NEG-NEG.fcs
#  - 89Y_CD45
# bad
#  - 141Pr_CD66
# bad
#  - 142Nd_HLA-DR
# bad
#  - 143Nd_CD3
# good
#  - 144Nd_CD64
# bad
#  - 145Nd_CD34
# good
#  - 146Nd_Histone_3
# good
#  - 147Sm_CD123
# good
#  - 148Nd_CD101
# good
#  - 149Sm_CD38
# bad
#  - 150Nd_CD2
# bad
#  - 151Eu_Ki67
# bad
#  - 152Sm_CD10
# good
#  - 153Eu_CD117
# good
#  - 154Sm_CX3CR1
# bad
#  - 155Gd_E3L
# bad
#  - 156Gd_CD172a
# good
#  - 158Gd_CD45RA
# bad
#  - 159Tb_CD14
# bad
#  - 160Gd_Siglec1
# good
#  - 161Dy_CD1c
# bad
#  - 162Dy_H4K20me3
# bad
#  - 163Dy_CD32
# bad
#  - 164Dy_CLEC12A
# good
#  - 165Ho_CD90
# bad
#  - 166Er_H3K27ac
# bad
#  - 167Er_CD16
# bad
#  - 168Er_CD11c
# bad
#  - 169Tm_CD33
# bad
#  - 170Er_Histone_4
# bad
#  - 171Yb_CD115
# bad
#  - 172Yb_BDCA2
# good
#  - 173Yb_CD49d
# bad
#  - 174Yb_H3K27me3
# bad
#  - 175Lu_H3K4me3
# bad
#  - 176Yb_CADM1
# good
#  - 194Pt_CD20
# good
#  - 198Pt_CD8
# bad
#  - 209Bi_CD11b
# bad
